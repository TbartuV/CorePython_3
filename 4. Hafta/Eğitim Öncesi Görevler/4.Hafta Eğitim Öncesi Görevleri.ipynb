# %% [markdown]
# # Problem 1
# Sözlükleri kullanarak bir telefon rehberi yazın. Bu rehberde kullanıcıya kimin telefonunu görüntülemek istediğini sorun ve kullanıcının girdiği isme göre o kişinin telefon numarasını yazdırın. Proje sonunda elde edeceğiniz çıktı  şuna benzer olmalı:
#
#
# Lütfen numarasını öğrenmek istediğiniz kişinin adını girin: Ahmet
#
# Ahmet isimli kişinin numarası şu şekildedir: 0532 678 13 19

# %%
telefon_rehberi = {
    "Ahmet": "0534 698 27 44",
    "Fatma": "0534 987 87 66",
    "Emre": "0502 876 77 32",
    "Fadime": "0534 485 40 49",
    "Alican": "0552 376 64 33"
}

isim = input("Lütfen numarasını öğrenmek istediğiniz kişinin adını girin: ")

if isim in telefon_rehberi:
    print(f"{isim} isimli kişinin numarası şu şekildedir: {telefon_rehberi[isim]}")
else:
    print(f"{isim} isimli kişi rehberde bulunamadı.")
# Out:
# Alican isimli kişinin numarası şu şekildedir: 0552 376 64 33

# %% [markdown]
# # Problem 2
# Sözlükleri kullanarak bir şirket çalışanları indeksi oluşturun. Bu isim indeksinde kişilerin isimleri key, kişilerin  memleket, yaş ve görev bilgileri value olmalıdır. Burada kullanacağımız value değerleri liste olmalıdır.
#
#
# Daha sonra bir isim sorgulama ekranı gibi kullanıcıya kimin bilgilerini görüntülemek istediğini
# sorun ve sorgulanan kişinin ekranda gösterilmesini sağlayın. Proje sonunda elde edeceğiniz çıktı şu şekilde olmalı:
#
#
# Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: Mehmet Yağız
#
# Mehmet Yağız= Memleket: Adana Yaş: 40 Görev: Direktör

# %%
calisanlar = {
    "Zeynep Aydemir": ["İstanbul", 29, "Veri Bilimcisi"],
    "Kerem Arslan": ["Ankara", 42, "Yapay Zeka Mühendisi"],
    "Elif Yılmaz": ["İzmir", 34, "Oyun Geliştirici"],
    "Canan Güneri": ["Bursa", 31, "UX Tasarımcısı"],
    "Mehmet Yağız": ["Adana", 40, "Direktör"],
    "Ozan Tekin": ["Antalya", 37, "Blockchain Uzmanı"],
    "Ece Korkmaz": ["Adana", 27, "Dijital Pazarlama Stratejisti"],
}

isim = input("Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: ")

if isim in calisanlar:
    memleket, yas, gorev = calisanlar[isim]
    print(f"{isim}= Memleket: {memleket} Yaş: {yas} Görev: {gorev}")
else:
    print(f"{isim} isimli çalışan rehberde bulunamadı.")
# Out:
# Mehmet Yağız= Memleket: Adana Yaş: 40 Görev: Direktör

# %% [markdown]
# # Problem 3
#
# 3 öğrenciden oluşan bir öğrenci not sözlüğü oluşturun. Bu sözlükte öğrencilerin notları value olarak bir listede toplansın.
#
# Kullanıcıya hangi öğrencinin notlarını görmek istediğini sorun. Öğrencinin notu görüntülendiğinde program sonunda şöyle bir çıktı elde etmelisiniz:
#
# ```
# Lütfen notlarını görmek istediğiniz öğrencinin adını girin: Mehmet
#
# Mehmet isimli öğrencinin      1.Sınav Notu:72
#                               2.Sınav Notu:66
#                               3.Sınav Notu:48
# Not Ortalaması: 62.0

# %%
ogrenciler = {
    "Defne Işık": [85, 78, 92],
    "Atlas Yıldırım": [74, 88, 91],
    "Lara Deniz": [67, 82, 75]
}

isim = input("Lütfen notlarını görmek istediğiniz öğrencinin adını girin: ")

if isim in ogrenciler:
    notlar = ogrenciler[isim]
    ortalama = sum(notlar) / len(notlar)
    print(f"{isim} isimli öğrencinin")
    for i, notu in enumerate(notlar, 1):
        print(f"    {i}.Sınav Notu: {notu}")
    print(f"Not Ortalaması: {ortalama:.1f}")
else:
    print(f"{isim} isimli öğrenci rehberde bulunamadı.")
# Out:
# Defne Işık isimli öğrencinin
#     1.Sınav Notu: 85
#     2.Sınav Notu: 78
#     3.Sınav Notu: 92
# Not Ortalaması: 85.0

# %% [markdown]
# # Problem 4

# %%
# 1-  "Bmw, Mercedes, Opel, Mazda" elemanlarına sahip bir liste oluşturunuz.
cars = ["Bmw", "Mercedes", "Opel", "Mazda"]

# 2-  Liste Kaç elemanlıdır?
print("Liste kaç elemanlıdır:", len(cars))

# 3-  Listenin ilk ve son elemanı nedir?
print("Listenin ilk elemanı:", cars[0])
print("Listenin son elemanı:", cars[-1])

# 4-  Mazda değerini Toyota ile değiştirin.
cars[cars.index("Mazda")] = "Toyota"
print("Mazda değerini Toyota ile değiştirdikten sonra:", cars)

# 5-  Listenin -2 indeksindeki değer nedir?
print("Listenin -2 indeksindeki değer:", cars[-2])

# 6-  Listenin ilk 3 elemanını alın.
print("Listenin ilk 3 elemanı:", cars[:3])

# 7-  Listenin son 2 elemanı yerine "Toyota" ve "Renault" değerlerini ekleyin.
cars[-2:] = ["Toyota", "Renault"]
print("Listenin son 2 elemanını değiştirdikten sonra:", cars)

# 8-  Listenin üzerine "Audi" ve "Nissan" değerlerini ekleyin.
cars.extend(["Audi", "Nissan"])
print("Listenin üzerine 'Audi' ve 'Nissan' ekledikten sonra:", cars)

# 9- Listenin son elemanını silin.
cars.pop()
print("Listenin son elemanını sildikten sonra:", cars)

# 10- Liste elemanlarını tersten yazdırınız.
print("Liste elemanlarının tersi:", cars[::-1])

# 11- Aşağıdaki verileri bir liste içinde saklayınız.
#      studentA: Yiğit Bilgi 2010, (70,60,70)
#      studentB: Sena Turan  1999, (80,80,70)
#      studentC: Ahmet Turan 1998, (80,70,90) 
students = [
    ["Yiğit Bilgi", 2010, [70, 60, 70]],
    ["Sena Turan", 1999, [80, 80, 70]],
    ["Ahmet Turan", 1998, [80, 70, 90]]
]

# 12- Liste elemanlarını ekrana yazdırınız.
for student in students:
    print(student)

# 13-  "Cenk" ismini listenin sonuna ekleyiniz.
names = ['Ali', 'Yağmur', 'Hakan', 'Deniz']
names.append("Cenk")
print("Cenk ismini ekledikten sonra:", names)

# 14-  "Sena" değerini listenin başına ekleyiniz.
names.insert(0, "Sena")
print("Sena ismini ekledikten sonra:", names)

# 15-  "Deniz" ismini listeden siliniz.
names.remove("Deniz")
print("Deniz ismini sildikten sonra:", names)

# 16-  "Ali" listenin bir elemanı mıdır?
print("Ali listenin bir elemanı mı?", "Ali" in names)

# 17-  Liste elemanlarını ters çevirin.
names.reverse()
print("Liste elemanlarını ters çevirdikten sonra:", names)

# 18-  Liste elemanlarını alfabetik olarak sıralayınız.
names.sort()
print("Liste elemanlarını alfabetik olarak sıraladıktan sonra:", names)

# 19-  years listesini rakamsal büyüklüğe göre sıralayınız.
years = [1998, 2000, 1998, 1987]
years.sort()
print("Years listesini rakamsal büyüklüğe göre sıraladıktan sonra:", years)

# 20-  str = "Chevrolet,Dacia" karakter dizisini listeye çeviriniz.
str_cars = "Chevrolet,Dacia"
car_list = str_cars.split(',')
print("Karakter dizisini listeye çevirdikten sonra:", car_list)

# 21- years dizisinde kaç tane 1998 değeri vardır?
print("Years dizisinde kaç tane 1998 değeri vardır:", years.count(1998))

# 22- years dizisinin tüm elemanlarını siliniz.
years.clear()
print("Years dizisinin tüm elemanlarını sildikten sonra:", years)

# 23- Kullanıcıdan alacağınız 3 tane marka bilgisini bir listede saklayınız.
user_brands = []
for i in range(3):
    brand = input(f"{i+1}. markayı giriniz: ")
    user_brands.append(brand)
print("Kullanıcıdan alınan markalar:", user_brands)
# Out:
# Liste kaç elemanlıdır: 4
# Listenin ilk elemanı: Bmw
# Listenin son elemanı: Mazda
# Mazda değerini Toyota ile değiştirdikten sonra: ['Bmw', 'Mercedes', 'Opel', 'Toyota']
# Listenin -2 indeksindeki değer: Opel
# Listenin ilk 3 elemanı: ['Bmw', 'Mercedes', 'Opel']
# Listenin son 2 elemanını değiştirdikten sonra: ['Bmw', 'Mercedes', 'Toyota', 'Renault']
# Listenin üzerine 'Audi' ve 'Nissan' ekledikten sonra: ['Bmw', 'Mercedes', 'Toyota', 'Renault', 'Audi', 'Nissan']
# Listenin son elemanını sildikten sonra: ['Bmw', 'Mercedes', 'Toyota', 'Renault', 'Audi']
# Liste elemanlarının tersi: ['Audi', 'Renault', 'Toyota', 'Mercedes', 'Bmw']
# ['Yiğit Bilgi', 2010, [70, 60, 70]]
# ['Sena Turan', 1999, [80, 80, 70]]
# ['Ahmet Turan', 1998, [80, 70, 90]]
# Cenk ismini ekledikten sonra: ['Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# Sena ismini ekledikten sonra: ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# Deniz ismini sildikten sonra: ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Cenk']
# Ali listenin bir elemanı mı? True
# Liste elemanlarını ters çevirdikten sonra: ['Cenk', 'Hakan', 'Yağmur', 'Ali', 'Sena']
# Liste elemanlarını alfabetik olarak sıraladıktan sonra: ['Ali', 'Cenk', 'Hakan', 'Sena', 'Yağmur']
# Years listesini rakamsal büyüklüğe göre sıraladıktan sonra: [1987, 1998, 1998, 2000]
# Karakter dizisini listeye çevirdikten sonra: ['Chevrolet', 'Dacia']
# Years dizisinde kaç tane 1998 değeri vardır: 2
# Years dizisinin tüm elemanlarını sildikten sonra: []
# Kullanıcıdan alınan markalar: ['bmw', 'mercdes', 'opel']
